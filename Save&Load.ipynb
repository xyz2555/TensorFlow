# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt
import numpy as np

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = keras.optimizers.Adam(learning_rate=0.001)
metrics = ["accuracy"]

model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

batch_size = 64
epochs = 5

model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    shuffle=True,
    verbose=2
)

model.evaluate(x_test, y_test, batch_size=batch_size, verbose=2)

# model.save('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/nn.h5')
# model.save('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/neural_net.keras')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 938/938 - 7s - 8ms/step - accuracy: 0.9140 - loss: 0.3059
# Epoch 2/5
# 938/938 - 4s - 4ms/step - accuracy: 0.9598 - loss: 0.1400
# Epoch 3/5
# 938/938 - 3s - 4ms/step - accuracy: 0.9718 - loss: 0.0969
# Epoch 4/5
# 938/938 - 3s - 4ms/step - accuracy: 0.9780 - loss: 0.0729
# Epoch 5/5
# 938/938 - 5s - 6ms/step - accuracy: 0.9835 - loss: 0.0577
# 157/157 - 0s - 3ms/step - accuracy: 0.9749 - loss: 0.0836
# [0.08360044658184052, 0.9749000072479248]

# %%
new_model = keras.models.load_model('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/nn.h5')
new_model.evaluate(x_test, y_test, verbose=2)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 313/313 - 1s - 3ms/step - accuracy: 0.9749 - loss: 0.0793
# [0.07928019016981125, 0.9749000072479248]

# %%
model.save.weigths('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/nn_weigths.h5')

model.load_weights('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/nn_weigths.h5')

# %%
json_string = model.to_json()

with open('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/nn_model.json', 'w') as f:
  f.write(json_string)

with open('/content/drive/MyDrive/Triad/Kuliah/Machine Learning/Model/TensorFlow/nn_model.json', 'r') as f:
  loaded_json_string = f.read()

new_model = keras.models.model_from_json(loaded_json_string)
print(new_model.summary())
